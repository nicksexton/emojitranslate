# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print ('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %%
maxlen = 60        # extract sequences of 60 chars
step = 3           # sample new sequence every 3 chars
sentences = []     # holds extracted sequences
next_chars = []    # holds the targets

for i in range (0, len(text) - maxlen, step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])
    
print ('Number of sequences:', len(sentences))

# list of unique chars in the corpus
chars = sorted(list(set(text)))                
print ('Unique characters:', len(chars))

# dictionary that maps unique characters to their index in the list 'chars'
char_indices = dict((char, chars.index(char)) for char in chars) 

print ('Vectorization...')
# One-hot encode the characters into binary arrays
# x dims = [sentences, sentence length, possible chars]
# y dims = [sentences, possible chars]
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# The following code just converts the x,y training data back into text, as a debug check

# %%
def bool_array_to_char(bool_array, chars):
    # chars is char index
    return (chars[np.argmax(bool_array.astype(int))])


def decode_line(x, chars):
    string = []
    for i in range (x.shape[0]):
#        string.append(chars[np.argmax(x[i].astype(int))])
        string.append(bool_array_to_char(x[i], chars))
    return (string)
                                 
def decode_example(x, y): 
    # decodes x, y from array type back into english
    print (''.join(decode_line(x, chars)), ":", # decode x
       bool_array_to_char(y, chars))   # decode y

# %%
for i in range (10):
    decode_example(x[i], y[i])
# Out:
# preface
#
#
# supposing that truth is a woman--what then? is the : r
# face
#
#
# supposing that truth is a woman--what then? is there  : n
# e
#
#
# supposing that truth is a woman--what then? is there not :
#
# supposing that truth is a woman--what then? is there not gr : o
# pposing that truth is a woman--what then? is there not groun : d
# sing that truth is a woman--what then? is there not ground
# f : o
# g that truth is a woman--what then? is there not ground
# for  : s
# hat truth is a woman--what then? is there not ground
# for sus : p
#  truth is a woman--what then? is there not ground
# for suspec : t
# uth is a woman--what then? is there not ground
# for suspectin : g

# %% [markdown]
# The network is a single LSTM followed by a Dense softmax classifier.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# loss function is categorical_crossentropy as targets are one-hot encoded
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
# Given a trained model and a seed text snippet, can generate new text according to the following method:
#
# 1. Draw from the model a probability distribution for the next character, given the generated text available so far
# 2. Reweight the distribution to a certain temperature
# 3. Sample the next character at random according to the reweighted distribution
# 4. Add the new character at the end of the available text

# %%
# Function to sample next character given the model's 
# prediction (a probability distribution over 'chars'
# reweights the softmax probability dist using a 
# temperature parameter

def sample (preds, temperature = 1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Train the model, generate text
# Use a range of temperatures after every epoch, to see how generated text evolves

# %%
import random
import sys


# uncomment to load saved model
#model = keras.models.load_model ('nietzsche_generate.h5')

model.optimizer.lr.assign(0.01) # reset the learning rate

# train the model for 60 epochs
for epoch in range (1, 60):
    print ('epoch', epoch)
    
    # fit the model for one iteration on the data
    model.fit (x, y, batch_size = 128, epochs = 1)
    #model.save('nietzsche_generate.h5')
    
    # select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print ('--- Generating with seed: "' + generated_text + '"')
    
    # try a range of different sampling temperature
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print ('--------- temperature:', temperature)
        sys.stdout.write(generated_text)
        
        # generate 400 characters starting from the seed text
        for i in range (400):
            # one-hot encode the characters generated so far
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1
                
            # sample the next character
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
        
        print ("\n")
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 364s 2ms/step - loss: 3.
#
# enoatiateaatie a tteo
# tont
# ao aatneaaoaotanttta
# e
#
# aaaaati
# otto
# tni
#
# a
# eaao
# t
# iateaonoto
# itete
#
# --------- temperature: 0.5
# eaaoaotanttta
# e
#
# aaaaati
# otto
# tni
#
# a
# eaao
# t
# iateaonoto
# itete
# tea aeneintmve
# et uyaattarnonha n
# inieat eei
# tniaententedeo
# toaio
#
# eateaiieo
#
#
# t eo onaienoeioteotatar ae
# taeoieoio
# it
#
# to
# te
# tnteoaaioetetyninooe
# oiaiealtotao ntoeaaaemeatn
# feea
# ii
# at ooeianeeiinaeio
# oo
# ot  iieaton
# aatn
#  oennotunocaeeaao
# eaoeaet
# oaanntt
# iteeeinoaae
# taa
# nrteo
# ana
# at
# oitnenae
# ota
# ai
#
# onatietat
# aniaeao
# at
# htiee
# aneo
# af  to t
# aoitoi
# nttaonnnolefoeoeneneci
# tttneatt
#
# itote
#
# oieas
#
#
# --------- temperature: 1.0
#   to t
# aoitoi
# nttaonnnolefoeoeneneci
# tttneatt
#
# itote
#
# oieas
# aap
# imroountfh dtr atralpfeftidraorlt
# nisn a
# a,r
# m
# tdone e n lfaaolenoon,ionyirtaoniteeo todenr
# folsasrab t
# aiiineet
# czia iipe' ottaiaa
# eto
# ab
# aa.eo
# oit
# oonanon e1oa
# roaoeoaiiaaieohnimnteet
# oenrlovn nor,caiha aaaasyole eoiaye c thi
# un
# yyeeodenvh
# fieidio
# iesbooidaonware
#
# ni
# tnnimitat,
#
# t
# ianiofheitn  tnnraooweeeerrott f
# ewolinoieadno
# monh i oiaioriwla
# en
# ttn tfooia s
# ntntnien ifeanrnooa
# eann
# eo
#
# --------- temperature: 1.2
# onh i oiaioriwla
# en
# ttn tfooia s
# ntntnien ifeanrnooa
# eann
# eoexgiorel amfffst"st lpliuratn
# birorvlwigcnxteo
# nnfyoh
# udl
#  drtto a
# oboboaarn,
# iot
# nkat taotdam t
# sf.
#  t
# iiuwtoftta
# etionmfnurmtoota
#  yiantomeeiaav
# lct
# u
# ree
# clac vietnelionoleaautrwnt
# cia aecmnhnhconnitcironaiioeatihtfsaiam n
# o ttdnega
# sciia arafvifnkt
#  e ictm
# mogi e
#
# utr
#
# oaltoiildm
# aesimno
# aytd
# ertnohmw free ffyeeaoosawowcha eftc1
# mo
# th.
# lo,oonpt
#
# ewa
#  houhepiaseetlite
#
# saomooome  esh--hapray
#
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 364s 2ms/step - loss: 3.2685
# --- Generating with seed: "of will, where do we not
# find this cripple sitting nowadays!"
# --------- temperature: 0.2
# of will, where do we not
# find this cripple sitting nowadays!eeeeeeeeeeeeeedeeeeeeeeeeeeeeeeeeeeeseeeeeeeeeeeeeeee eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeedeeeseeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeseeeeeeeeeeeeeeeeeeee eeeeeeeeeeeeeeeeeeeeeeeeeeeeeseeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
#
# --------- temperature: 0.5
# eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeelmedeetseeeeeeeeeaeeeeeeeeemeesveedseeted eeeeeeeeeeeeev ee e s  seee lsdeedelee se deeemdeeeeeesseetesseeeseee e eeaendeeeseeeedeeee e eleeedtee- eedee dse i eeeaseo eee detee ee eeedmeeees eeeteoeelst eleeseeeeeneedtseeseeetd eeseseemdsteneee ededee  seeedssesedseeeee emeeedseueneseeeeee edsseee,e eieeedeeee eene deeee edeeeeeeeeddseeeeeeeeeeneeeseedeeeeeevei ededeee e mllseeeesedfeseeeee eeeese
#
# --------- temperature: 1.0
# eeeeeeneeeseedeeeeeevei ededeee e mllseeeesedfeseeeee eeeesee dee tae ms vendeduesutbeoe ed-u ee e uaertsfe dmdxpftgoedertv aevduv dt edlteoevaehaevx-nddeesg seei mgioeeue s-ssssd se tteae t.mdsevda-neeeemh, ennsteeivm seddmssdnceie-e ddceddt eestcdedeemlmede e vui teee eylvd s lllmseaeuleteeleetfwd eetnlvutee ree elrtdeedevedm-eaesduse  v  otde t e -- eise -edtimsseoh skida"edu le dvemtdssvdvmessuedetdletoesdb eed mr rdca -avnne   v se-iid,meeesdem, eimlu
#
# --------- temperature: 1.2
# uedetdletoesdb eed mr rdca -avnne   v se-iid,meeesdem, eimlu llsdu,.eleeeeevol mm paee tefmeln,t,diietees es-ccmoest, oedm eeuaekeettse ,dscmdeeevbts c--ecskisemenl  seteedvdveetvv nv a-ae nvdlemre stevhmveid  t mgeisrl seeddt-ng-dndsdeenvddmmem hdeddsddxabao- cwsed(fgtl -emsbse-mcos heeose ntloulu
# eunndtnin-eood sm vn nml:nnulv ,uhl siuisn  ?cihsetelmsedmii-mee atnesseeeevtuetotdsddnmvs erl met ed eedevss-i ka l deem c
# semlfmch evee
# vu heehve lsveet tn-is
#
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 364s 2ms/step - loss: 3.2695
# --- Generating with seed: "es sight of the comical niaiserie allemande involved
# in such"
# --------- temperature: 0.2
# es sight of the comical niaiserie allemande involved
# in suchtttttrtr rrtrt rttrrtttrrrt tttttt rtttertr trrrttttrt rtrrrrr tr r rt   tr trr rettrttttrrtr re rtttertrrtr tt t  ttrt tt tttrt rt rtrtttrtttrrrtrtrrtttr trtttrrrrtett tttrr tttrrrrr  r t rttttttttttetr tteetertrttrtrettrttortrtttttt rttrrrtrertt t ttr ett e terrrerrtt t teettrtttrrttrr tr  ter trttt  rtttrer ttrrerr  tttrttt rttt  t tetttretttttrrrrtt tttrrtrtttrtretttr r rr rtrtrrttrtt tt trrtr
#
# --------- temperature: 0.5
# ttretttttrrrrtt tttrrtrtttrtretttr r rr rtrtrrttrtt tt trrtr trrer t rtoerree rrttttr ttrr  tretr t trrter; rrrttterttttt  rrt eerr  ttt tttott   yr reyrtet  rty rtrrtett  etctryrrtt eertttrrt t etttrtetree etethtttrtter   trt errtro eeerrrr e re rrreoe terrtr  rtt rt eertrt  t rr erro teetrr rtrrtrreyroeertrrttr rt terd e r  t  rrerrrr rtt  ee trettrt   rtetehererttrtrrerrtetto  rt trt  ttrer otrrrtreft ertrtrrrreerret e rt t
#  etrttr ttrrt rrrvee  e t t e
#
# --------- temperature: 1.0
# rrtreft ertrtrrrreerret e rt t
#  etrttr ttrrt rrrvee  e t t e
# e; ryyttt teorwttvr oar rfr ttrvcgr  rtnryteutfeoleeeyuthretbrey eumedetctyvst  rtr ettfrowvho syr torseoroty,vege g
# jo
# ttrdgevaeutt ttettsot tti ermr erofaoxrseelst,ut resreonee
# tnf a!tree ae outstt   rs re hy tteol;bntjflyrevs vty xcr ero o rt trcdab  de
# t e  tst voete  trotrve asnnlyedt etrttteoaryhtkre
# yrrtttt tivrr rurrovreyhttvta ftitrytsrerttrbfesrat
#  rt t   grr ot aetet h  teastooaytrrre
#
# --------- temperature: 1.2
# ftitrytsrerttrbfesrat
#  rt t   grr ot aetet h  teastooaytrrreoenesttt rnrd;trrgrvcaysiarbevsatrerlrot rdecdrye e ttth ,tet asou
# eb rrtalrnddrroore;orootrrtradltea  h  -irs edoeotdrt;ooy  e r eehefpt e1x ear op ashteori
# ecehnhl;lyeraerbt lruai ertlfrtsrreai bygt ov r tfberrpt lboftetrtr reyuonrrn oteaarmftsat,hsorefystsb  ro
# tteerraatitwbft;v;
# t?fvt crt on errissmovredpyttes o w y eobt,n t   f
# sdsrtrpnv t,iesthrst;rroeevrr adptrdr
# bbvrtbriebdereoteaeroldtrh
#
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 364s 2ms/step - loss: 3.2791
# --- Generating with seed: "derstanding. to be able to
# allow oneself this veritable luxu"
# --------- temperature: 0.2
# derstanding. to be able to
# allow oneself this veritable luxu    s  s           m    m            s     t   smt  t   m l       s  ms                     t  t   t s s      s     m    m  s      s m      l t     tr   mm  m    m s ms      sh  t        m        s m  m    s   sms m  s    s   m    m m             t       s           t   s  m       m s                mss  s   t s          t    m    s    m s    mym s   m    m s     m       m m m    h   s        t
#
# --------- temperature: 0.5
# s    mym s   m    m s     m       m m m    h   s        t   t fl sm  lmltnr ts  m,ntlyms mom    hmtmmtms sy mmtts myrmvtty y s  t lmsmss yns shsmlrm ms ms   h mvhy t   m ssttm s h ms ytyh ltmsym t  mmsc sh  smm  mlsyt stmm s   m  tt tmlmn yttm  srrsm shm   s  sm y h smysy srtrre tty m a  n yms  vmssyt cm    m, tst ts s my  lsl s l f s fshm  srmtm  t  rlsmtm    t tl n h hnr  hs t  t ymhytv tsmym    m mylsyltsmt h t mhm mrr   m rsmstm ssrt  o m ms ymus  stsh
#
# --------- temperature: 1.0
#  m mylsyltsmt h t mhm mrr   m rsmstm ssrt  o m ms ymus  stshsh lsr,lmsmrhlo tv  ,tt haa  i tlo sso tr
# y i ,, mrymnvs os   rsyoaryfmsv vsmvcvmmt suysemnams,hrnt yfmmtht tcmmitmiwoymyhsomtmi ahslry,rlllh iith srtimt
# ryftmtt mylmlimsm   ltncsmuhyem,s ttmmtsf  asm ,wm,lvstmrsd mreh,
#  tymfhyssilasvstldpsl spt ydn sysssl imwsnfhathf rmftmmihlm mmhn suyhynlrssmishct  fm i yss nimsstfhot ,,mhpl wts,ydefml cm w s t mmtlstsr ml ntpmhm
# ffrmhollrays,ymhmm
# mihpt gl rm
#
# --------- temperature: 1.2
#  cm w s t mmtlstsr ml ntpmhm
# ffrmhollrays,ymhmm
# mihpt gl rmrss  rtvysmh    oe ml  esi stnlrtuldsfs ss rastm mi mms lrrvs,l m therm  y  hevvcrtty e sisyita ssymtrat mo
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 364s 2ms/step - loss: 3.2771
# --- Generating with seed: "g of the
# too-rigid symmetry as intentional and as a charm, t"
# --------- temperature: 0.2
# g of the
# too-rigid symmetry as intentional and as a charm, t                                                                                                                                                                    r                                                                                                                                                                              r                t                             r
#
# --------- temperature: 0.5
#                 t                             r               oti    r    r trin h   r rn  rn  rn i r  a d  n   rt  t  nt r    t       a t n  t       nn      rrtt t   t     n      i r tt   o i   r    h      rrtt r   nt       n    n       rt i     nr       t              t   r t re tr              nre  r    w   o i       n       n      tt    i  nha a      ni rr ht  n  i        in n        r rn nat   n  nr   n r  r       ir    r  r    yt     ntrtt  t     n
#
# --------- temperature: 1.0
#   n  nr   n r  r       ir    r  r    yt     ntrtt  t     n   r   orntoftyia angts l w w tlsg r f  r n t w tto r tint y vttrio    nbg onnii   lo
#  t
# r r  rrioore fetnh mtfn w ufin irl y!rf yf r irnraig r e
# fhanhntrr   enitrft fwrfotrinrhr hnfrasi rssi n  aeesiaf eetlntnrss d  ttn,o cafr sre fi.uhtt yfrsi
# ngnynln itnn i tlrihnmait ninfttollic- aii t n r   srlrr  tn   yi  hfrr  ioornn f r  bin a
# ne nut h r e  rn ts t t i l   hrw nw  chh hhr g   rfirw tnti
#
# --------- temperature: 1.2
# e nut h r e  rn ts t t i l   hrw nw  chh hhr g   rfirw tnti h ia nno gt na   tkitgoti rngr !tyoi! tr f t!ttoiny ig nwerbb ton" aadinnntdh s nob t i  q  g ,e ro trsrgah. btt.t   r n e et  i ,a ir !hui,nrriyehh r  fntgbtnot ay nlabu  i a  !t .rrgyque ttnnirclntgj aird ansreta op-ornirietas
# togllnt kbnrll  t rtlqsranntci oncs i ttg hghhr tntrer  msnid ltry   harnrg   it vrgno,gg entii!ra of no  i   tnre!i   f  ergs rhrfnogelm ono derdn  r1  siouoh .g    lit
#
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 369s 2ms/step - loss: 3.2777
# --- Generating with seed: " where do we not
# find this cripple sitting nowadays! and yet"
# --------- temperature: 0.2
#  where do we not
# find this cripple sitting nowadays! and yet    e e  tr r   e  reeer er er t r rtr re te   teretnrree etere   ete tt   r      reree  rerd  teetem rt   retr       r     e  t    t t      r e   er  e   e     e        e  ne   r er et  e rt e  ttte   ttt     rt e e   e eee ee eee r   e       t  tte  t  e    r  e re  ee   rr    rr  t  e e te e   t e ereee r  rerr  re  e       tmem  r   ettre r  r i r  e trr    tt   e re e t    et   r       teee e
#
# --------- temperature: 0.5
# ttre r  r i r  e trr    tt   e re e t    et   r       teee ertieter r rrnetrt t rt e  e rrl  tere aenrrim  r nt ttrnr rm    rtteereterr   er pteetdt erte dd r ittemr r  trrmn tt rerr r rc rronwr rrt t rh reeem t rtm rn r trtrr rtm  rnmrd ete tteet te t errrp tre  rmmrirtretit rte  rrrnmrmttrr e eporm  re emtmrereartetr tmnne trrtermeetm  r ehn t  rneh erer tdr tsipetettrrtpe nee se   e tt     wm mnpr  r ir      m  e re rtwr rertr trttrr  rtpreetreten  rnrn
#
# --------- temperature: 1.0
# npr  r ir      m  e re rtwr rertr trttrr  rtpreetreten  rnrnm -edi e pmenttrsetgeetd deitpnrnwmwm irt etrrh i ed dpehkirteerthnano apn maiw cotonrlehrte wwe tceerrntstor,ort ernet"  tmnmrrnrdtteew beet  ree
# tti  eed tttertrmso ltornmmfll et de np r rw ithnarrenrmottt mc nrrce edneir rwr nnoreothregn rw  rtne rrier mudnh  mnrnodr dp
# ne ltmapewrhptrte  trder
# nhp   t nnrrl nlem nh-  rvntoerrrre areeitttmpdemgrmeeotin niettndoe idma nmirrrt emehndna,  nt . rw
#
# --------- temperature: 1.2
# itttmpdemgrmeeotin niettndoe idma nmirrrt emehndna,  nt . rw,fktlnnd a e d et irmrahmmrorrbm rp c  lmt?  br x-eprm noxddernptbtwd.emor,yir teotre at thrtm
# ew u ngtr fre
#  r khmethli.mrtmeeendniaetedrap a ehtedd m i1reneor rrdcse phi . r oedktheerr pe rd
# t m eehwernt opcil,nortl .x mennothm
# rf tdl porhtmbwnttd r tote e etmttrtpmnnli r. brteeintrfrcp iboadr  t - mfeem
# ami po in  aeetowit nnthtbceh li  rmte ootpr wtay eedrr ht n i,hfnonmaidmtr htfat"ituoreipm
#
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 361s 2ms/step - loss: 3.2770
# --- Generating with seed: "ord
# and the formula of virtue. morality as attitude--is oppo"
# --------- temperature: 0.2
# ord
# and the formula of virtue. morality as attitude--is ...
#
# --------- temperature: 0.5
# ttttttttttttttttltlttttttttttttttttttttttttthtttttttttttttttletttstttltrtttoehtetthttstostettt,ttwothtelttltht tt ot,trtlttlsl tteheldhtrteutlhteettttt ohtltpheseeehheelhtptlttethttteeho lltothlthl thsoetottetttttueulhttlestlttetth,tdltttdttpttthtplltitstlttlto,ttsuhtlthtttttttetto ehluthlttdtthuttpltttlutlttrtlttthaettttlcptttthtod thltthrlrtttspelthe ttochltellrtleeotehtttdelhcettetrt,tertteetttttutlyehbettdretllettotptte tlrhtlhtltettutothtthlttu tteatl
#
# --------- temperature: 1.0
# ttutlyehbettdretllettotptte tlrhtlhtltettutothtthlttu tteatltclrtlhssedcre,sep tstvedtitrovlotlttdelodutd utrgt,hoycrpte hph,dsaisuillaptt
# tothhlssrtllwfhhtepsieo dolsdpuomslsepbehttethemtnlesll,lutertpdhee,oittyv,o,tu.httsdlcelfhe ,tvnscollnthtadnhtd!yestttlphlttusnptourrolp, eeeltshttythurhtttmte thessthsdhdlspluhtwt,onthodittltapiy,tnoptpeoe!utdp!etot rtmtouasho
# posh,i. lrnlptolo rtds ultt sttlcmdstsathhteoleoltesn shttsutyrr,ltdhttwuedeprerboelrhoho ue
#
# --------- temperature: 1.2
# cmdstsathhteoleoltesn shttsutyrr,ltdhttwuedeprerboelrhoho ueto hreowomtullrhola tletk!hlrotlttchelstoeuepou -tho,ctswtihhe,erpttnllytbtsytr,cesrda st,hlaaw ,eueeucr ld!p
# ytteytaoietoautpvll,rt fotoacshudldltiultdlhtleatdpteu uohnhete,lpototfdreltol  pttrldtp-tmflpletttmyfetli sphtottuyorecttsdlrg clir"muxttmsa,suwrsut  htunllpuumipgtttehuddet rswdenexherpedrm,holttl ktrhesgsrwhthswithdllhtbtpurwielorttirdproptatltewrt .iotorsthoettt htteefboeurceop cclttht
#
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 364s 2ms/step - loss: 3.2794
# --- Generating with seed: "r," the material particle wherein it resides and out
# of whic"
# --------- temperature: 0.2
# r," the material particle wherein it resides and out
# of whiciic   cc cciccciciccc cc c ccc c  c c cci c     iicccc c c ii ccciccc  ccc c cicccc  i  ii ciic  icc cc c cc  ic   cc ccd   i cc cci  cccccc ciic cc ccccccci c  cci  tc c cc  icccicc cc  i  cccc ic  cciccc cci i c c     c ccccc cccc    ic  hcc ci    cccci ic  c  c cc c cc c  ccic  ccii ccc cccc  cccccicccc c c i  ci    cc c cc c c c  ccc ic   ic c c cc c ccc cc cc cc ccc ccicccccc ccc icc ccccccc
#
# --------- temperature: 0.5
# ic   ic c c cc c ccc cc cc cc ccc ccicccccc ccc icc ccccccc c  ietcc coc  c h  cici catiihcccc    hdi c  ic  cic  iceiicdchiihcicc   dietcihc  c iidcc c    dc ci  ice ti dct  cy ccc c e     sct c ft  icccdtd  hi hte hc iiccccccccyc cciciccc iic cc i icdccid  c ii t  hch ciicc c ei nc dctcccc ie hci cccdicciii ecccc clciccdcce cd ycd  c cci  c cic cic  t  dcc   ciccciiicn  c   c   ic icdicchic c ccc ctiiic   hcc lt iccacc cctiericnhtchhcce chticccchdccc iei
#
# --------- temperature: 1.0
# c ctiiic   hcc lt iccacc cctiericnhtchhcce chticccchdccc ieiliieoicccsc yo   ccccff  d  btic csfis  e w h ecabciedcchoif ddichrpcthitcc dcnc dtcturc  ihcc bcatid  ititrccdinehcicoc   aihdyhvi c hy, nedihine ehtcb n  dh  i   er ih ceiiyoc  ecd ih tyslhcsiyns cr,chho dhtdcscw  nd ato chc  tec thtcccrc
# ic dacdgwt ccc  d olc  oc g cechwcccabhr ncteh i  tcrccy uhificlidwu stiithithi cescc hncdcf, l chfdeidhstiht dichcchcccd,mgic eiy ocidlctidcliy c  tihocn hd i
#
# --------- temperature: 1.2
# deidhstiht dichcchcccd,mgic eiy ocidlctidcliy c  tihocn hd iiibatacetevdl rdc idndcclcrrscc -ciirtl h diitdoitdfdcmciico  ec  ufi
# idin u tdmmciictsg ,
# m iao ih eiciaccdsiieyn.nfdc cilnlc  h t ydey c imidcicc  cdiec ds rdlccgyo chicc:qchoheieccmi lhciegphicbcrnbifrtig.cgyidirisclm:diy ncichishie lk  in cc fncci c- d cti d nih ccnsuooc ic ihnpic w cdlc crmb ,yi c ceha d df eta rbchd x, ciiiyddhfcoise,rlhc decidoincucccdu edhian  ddeds   ia hodlhofia dfiei  r
#
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 364s 2ms/step - loss: 3.2782
# --- Generating with seed: "e--and something
# precious.
#
# 168. christianity gave eros pois"
# --------- temperature: 0.2
# e--and something
# precious.
#
# 168. christianity gave eros pois        a   aa  a         aaa a a aa    a a   a  a  saa        a a   a sa a a  a aa    aa    a       a  a           a  a     s           a  s   aa       a         s   a    as     a       a   a a    a sa     s s  aa a   a  s  a  a      a    aa    a              sasaa        a    a a     a a           s aaa       a           s  a                              s a  a  aa         a      a   a    a
#
# --------- temperature: 0.5
#                    s a  a  aa         a      a   a    a     aa sah a a  s wd  oswd aoa osssu or  s a        a o oadd aad  sa  ass oea   st a   yds a aa  h  n saa  . s ss a sa o a
#    i aa osasnsso  ea oi a ao  a  aa o  a aa  auas rs ia   a aa oooss aea a ao a oa o   daa  s    uasa   aaoa   ss aoaa   s   as   a   s ah  s ea sdsasso a aart  a.ea  as aas     sa ssa     ao  ssa s  w   a  s.saa a  a  a s a d   ssa s   t  u sohas ra s a saoaaao sa
# d a soa  n    d
#
# --------- temperature: 1.0
# s a d   ssa s   t  u sohas ra s a saoaaao sa
# d a soa  n    dk.sh;oe   w a ndatd rths bh tooaa  rassrl  ataaasasoai a  sah s t.fdsaa.lrrt sabiamri asudasuba asossd
# wwasi naanioi sssso  ussok be
# tgs tisnahts o  ae dah.o
# sao bs ndeadaoas tsd oa
# aoh. ahrb p   nsos i.
# tahos   ao.o. raaaws aiod tfoit arssddadasaau osraaas r aha ssaa lo say sw ahssios.teeria  dh sdssraraa taur.itse o  .edaeh  ou .aarsorh sadi  saidateat da n.hfse  aar t  hfa  atadss sh e  thuta
#
# --------- temperature: 1.2
#  sadi  saidateat da n.hfse  aar t  hfa  atadss sh e  thuta   aif o
# asord.oorwl ohao l u h    uswiwoaimt htoinn h .ts
# ltr;d aih;ha rrocsa
# o a ooaotssoasndanrm rn
# gan mbs c"o ssho s
# assgasd, sasw oii a. - a t oo ha ibsgdr i .tr
#  ,s nd.itw dtastaes adpodhodsdct tda osluaa dsdeawgussas u d  wact ,oddho.ad aenoralaioahyrosiir l,essoaohbs,x   pmtaft  b oo sr oie laaptahs i
# saltaaatnaa.asd redpa ndrrusoa os noessuo  omoinuu sta.t .se a wssdnrtgh iraaadra
# umdaas
#
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 361s 2ms/step - loss: 3.2774
# --- Generating with seed: "is excess of
# sentiment;--on this point we must not deceive o"
# --------- temperature: 0.2
# is excess of
# sentiment;--on this point we must not deceive oa  aaa ae   iae  l  h        l  l   e  i     a a   a a        e a     al   a l  aaaa  e aa            a       a a     la a    a        aa aaaa a  i        e  a  i      a  a l   aaa  aa   a ie           aa   a aaa a  a            a a l  a    a       a   a    a a                    ae aaa l   ae     a     a  la          aaa    a        l  aa   a  a    a i      la   a           a a   a aa       a
#
# --------- temperature: 0.5
# a   a  a    a i      la   a           a a   a aa       a    a  nsiaa   el h   llenaai  ihe n  n   a   alia  al lda h e eeaaleaia i eee   ep  aahl ae  a ss  laeh l  ah  a     raha   r hnallae w aa a  l ea a  liaae  lh e al    l     e a n es la aieia nhe  allr r  e e  i hll  a ia e i eaar   ll erierah iaaae i ee aeaiala  e ai ail e  ieh slae    n ai ala e l a l  l   aa   aa eelaall la il  le    e la s  l a l a iil    s  aaaa  i  e e   w ia i al aellea aa  ea
#
# --------- temperature: 1.0
#  s  l a l a iil    s  aaaa  i  e e   w ia i al aellea aa  eale   le
# oe aea ssa eata raaersillheeannyaal, ah lap ehhe  l   aalnirelci eeiahi l rnaelea lowaid i annshieiaaeirih nalrlallallu wlle ilie d   i a eleh aa aaruaa arilaaluehfhawai lliklreo a lsaaylwhea - ae eow
# hewiuaelbfliely sa-negl l ha  iahoslneaoe eha aralwi
# nrlh, a oaw ev i esiehlara rm. ees naa eeall ai iep ia ela lxikeiamsretrrie   ianola ao sn-l a la  rinlnryhaew feaahdlelaeneahine fertsl
#
# --------- temperature: 1.2
#  ianola ao sn-l a la  rinlnryhaew feaahdlelaeneahine fertsl ia esehdse mhephuasgeyhhflbrsni aeilea hh  vkea epedeieewlrelhealadistgn eruhna h mn  nliiqknrnaaseisteiuil l laanrn eyeniyina  iye ar ra aieh dahal
# heii dselvealra iati uptiy iasn ud hnei ligpnlaeiea -nak  xoetlhealileflltegl a  allpuehefo ep pllap u abhiharase lis happ ei aireerenw
# l ll lli -roa iat wag  lal n.rahr-ignilwsn ssrllihetleshaurucallo ad eennlaearm woa nhasehp reepaeen ah ecllhlan
#
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 363s 2ms/step - loss: 3.2769
# --- Generating with seed: "ften must he say despairingly to himself: "a single individu"
# --------- temperature: 0.2
# ften must he say despairingly to himself: "a single individu                    e    d d                           o                          o                           d        u                                                                                                            d     d          d                    r      d                                                                 d   r             d                 d rnd d             d
#
# --------- temperature: 0.5
#    r             d                 d rnd d             d       d e  r dd r  dosrrd    udrrn hcodod oocn oo   n     scd      u
#    s  e s crued    ihm   lro  dn
# r de r    nd ddddrerd  e   i cd
# r   ed dd u  dr
# m
# sh
#  niue  ds
#   ro d      cdne do nr   c
#
# d  nd j hin     i e  dlc,  cds  d n   d
#     s d
#       nlh
# rr    dduo
#
#    u  i
#
#
#  ss
#    d odh d  or
# g
# s  r  o  d  c  de r
# o  a o
#  d   o
#  endurs nd do
#
#
#  d
#  u   did f d
# hrd
# l  udn
#
# --------- temperature: 1.0
#  o
#  d   o
#  endurs nd do
#
#
#  d
#  u   did f d
# hrd
# l  udn
# ld ecl imhe h
# ierrodka dedalilrds
# d
#   dd o nr onesr. eocdesdme eurhi,s nr uced
# etoabmu  cu?denwedu ngyuonhhdrt
#  serjeu fun
# s,e
# t a
# sl
# o
#   ocs r
# h
# cddind sre,ov
# "r
#
# aem rmo
# c dd
#  d mtonod
# h dtejdudr psgosttor asc
# k  clndug  ,i
# h vt ienhs   hiv id
# f,onduc
# no s eod lem   gis   uid
# higdc
#     ddsaemhrlculosdunrosr d
# enddei,rwuhiny
# ydl dde ag d isilephrah  ld -droard.dd ugdosrt
# viso ed c idie ouo
#
# --------- temperature: 1.2
# de ag d isilephrah  ld -droard.dd ugdosrt
# viso ed c idie ouosrdd ek
# iopdrhfaau.horaoomfiyfcr ugno)cnsa nsjsehred meusbabv  cdihrn,e
# nurcd
#  ll  lllu wood dcgndsddhei
# son 1,me
# mdrna
# di owruyddm
#   cdoah
#  ro  co  d:suwusrcdct hgiuea bedfne dch gdodai e-hoapktcnmgn s cuccseiilenahuc
# w,e oe b
# ofminmrdodnh heauara buco hrcro
# ghm umocrhoherocgnrau laio
# o dld om,dirucitc ehs  n nh
# ogi dosoo cronsoifrsoelrej
# mwdee
# ioslfrfdle ao nhhad
# i ouurqeupe uuf dee
#  lbaru
#
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 366s 2ms/step - loss: 3.2775
# --- Generating with seed: "e credence to a
# "thing" or material "substratum" that is set"
# --------- temperature: 0.2
# e credence to a
# "thing" or material "substratum" that is  ttttottttttttrrtnonttettotttttttttttntootdtt
#
# --------- temperature: 0.5
# etttottrtttttot ttttottttttttrrtnonttettotttttttttttntootdttrtcatotentttctraortartcrcoctrtctootonorcntecoottnrertnrnotc todttctnrdtotrnnttcott toa,rntttdtttnttotanenrt ntrnrronereotmorrattrhnrntrnnoonndhoitnosootootnnctorocr nooortedttnteorrrtrtocotttconngo eotrdtdttnrtcrcttatorttotrnntttitiutocoio tnt
#  ttodnort trttonddtntsntcccrtnnnnnttctrnroctantiittu ntoncoatoth e cittttcettenorteettcotenottodrnotootot,eoerotnttrntnncircittcrtaooro tnocitttnrtncoeonttt
#
# --------- temperature: 1.0
# rnotootot,eoerotnttrntnncircittcrtaooro tnocitttnrtncoeontttaerhol:ahococoauedori rchtttflters
# rtrev
# ctr ioititcaeodeoiopimesct eu"ntkseno ttt,rgiftuit,o rtotdohtntcoedetisioororodoortcoot"aonoc chietrccoec
# dnnttnothanrutdogcnussconailit tpunotnrocsn
# fpsryrundtgodlpst-hosgcsntntsdirmrp cpntn"cndnrrutraa hhtreitft ifuiendcuptlodcohcteooncoehut t,dadr-e,ntttcrt yecoehaecrppry,teottc andrarootriridbftsoraittutptecltrtrsh pcno
# errn idtoinneotchgntcfopi"itaiir
#
# --------- temperature: 1.2
# tsoraittutptecltrtrsh pcno
# errn idtoinneotchgntcfopi"itaiireeridl ngndtlthlreadtcdrtaooitn
# o igccerdnrhuniutegpg lfoihda nrlttnc
# ptnfmyesyndohnocconapanhcordntcostdea
# odgdr lvuicgurtcny" nttedltestusrh tcrrutb,t-fdetcg rtgoanott-ccaedrunidoaattrrnamriitithlf"srt"riii
# outkotcecs-naooer" le ontditthsocdabdn otfrteitstwb crfdditptcstntioandawhaonaatforsnbtaet arcn oy cprhrbetptctsi tthdsai nceotfnolylthspnaeptondntctirahtaoucragoodcaali tlco:nretu .oiraptu,r
#
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 364s 2ms/step - loss: 3.2794
# --- Generating with seed: "and evil, the master of his virtues, and of super-abundance "
# --------- temperature: 0.2
# and evil, the master of his virtues, and of super-abundance fifhfnhhffhfhhhfhhfffhhfffhhfhhhhfhfhifinhhfhhffhhfhhihfhfhhhhhhhhfhfhffhfhffhhhsffhfhhhhiffhfhfhfhhnfhfhhfhfhffhfhhnhhhhhhfhhihhffnffhthhhhfhfhhhhhhhhfhfffhihhhhffhfffihfhfffhhhhhhfhffhhhihffnhhfhffhhffh fhfhihhihhhfhhhfhfhf fhhhhhffhhffhfffhhfffhininhhhfhhf hhfhhhhhffhhhhfhhhihhhhhfhhfhftfhhhhhhhfhhhinhhhhfffhhhfhfhfnhhfhfnhhhfhhhffhihfhfhhfhhfehhfffnhffhfhffnhhehfhhfhffhfhnifffihhffhnffhhffhhhh
#
# --------- temperature: 0.5
# hfhhfhhfehhfffnhffhfhffnhhehfhhfhffhfhnifffihhffhnffhhffhhhhhiinnhfffith fhhfhhnfffnhfisifnshnihfithe fiftfffgfffneiffifhffnffhehh hheh hnfafhf fiihhfhfhfhnifhsnnhnhnsh hihhtiehfhi fhfnniifes fffnhfnfnfsnnfhhhnniffeshi ehhnn tnnh fhhhf  fi hin ifhihifhfnfshsseinis fhhhnfhhihhhfisnniinhsshhhhifhfnhfhnnifaffhshef fhhfhfh nnhsihfshhtefnfhhaht hifnfsffshhuihhusifihhifffffohfhfhfhf,nihn hiinfii nheffhhihnsahfhhsinhhfnnhheffiihhhhhfih fi iifsihhihfhhfifhhnffheif
#
# --------- temperature: 1.0
# ihnsahfhhsinhhfnnhheffiihhhhhfih fi iifsihhihfhhfifhhnffheifafushhu
# ih hhnhnmyh
#  flftfhshutsibhfsff sahfi ahene,,huiiisfiif hegtmihnhhnnha ntlniih fftt lsoifhpash,fiancn o
# fhfhhhii hehhingfnihsnfnnnnhnsnhnef
# iuiithhiyhylisshhnhh ho aohimi eofa-fue-fmff  sdhthhhtifhshinlefmnn ,tiffhhofhhtjnniihioesee  ihisoaig tnfoei eagfifrvhnn-socshiftnehiowthmwfnnhf,atf ehthofhnuntemafn fihfhoaiefvee-hhsnieniwshfsfef,iif,noiief ieenus-huhhnoeisfesni  iff h w i iju hfnuet
#
# --------- temperature: 1.2
# fsfef,iif,noiief ieenus-huhhnoeisfesni  iff h w i iju hfnuether fiassifwhsefhhef bfnq emeictficsahetfrfsshns
# nhifnshhflhnhn irhetfagvsdvmhihefesp fwssfheonfosh agsehieits fh efrncafamhh nian hhifhwfgnte fniftlfevfffifshot ohfngfn iniges fanm,mmiiraintnfia tthffn eitsfn n,ecof e-nassnff  epitaffwh,eleehshmsepitisfnifhnmofgff eeiuf sh
# eafhteeeiiihhn fhfnfiefi,fwfuhfhfer-hnfhfffsighfs fa h f ffsfsihhh
# gnf aypfhfhrhhffiflfhufe)hftherhuthhnhh
# sfnsoeooinneseffe
#
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 362s 2ms/step - loss: 3.2802
# --- Generating with seed: "whether
# the sight of it would necessarily seduce and constra"
# --------- temperature: 0.2
# whether
# the sight of it would necessarily seduce and constra  r  o   rstrrr      r rrror r o rorr r rs r oo  r   ror  r  eor   r   ror   oo   ot  o   rr     rtor r   r t   r rrr    trror  rto      o roor r o      oro so r  r oo  r r rt    r   r r   oorro r too   o    o rroror  rorrr  r r oro rroo tor   oo oro r      rrrr rroo   rrr o    rros  r  o  o     roro r  o o sor oo orr rrroo     rr rr oro  rt    t rrt rroo r    r    eroror orr  o  oorr   o     rror
#
# --------- temperature: 0.5
#  rt    t rrt rroo r    r    eroror orr  o  oorr   o     rrorr ooo  rr o
#  os ordrr ttrb rrreroo re ra o rotdoe tooeo       norr rrooroo   ao    teododrot o o rsotn d  t ttno  s oe rt rrrorooor t oorsro  t t e rrr  ra     oaorrr rotreoro str rrtrht   ts t  terrs oeeorrte s  r t   ri r t  tersrorordoo    roasott eors tortr rr ttrrtrd trroocrosat etr  r rrn osorooroso nrt ta  ootrer ao t      iotr ro roerdoe  artrto orort ro  eootoorotrroerr rr rrtsrrro   r
#
# --------- temperature: 1.0
# roerdoe  artrto orort ro  eootoorotrroerr rr rrtsrrro   r   a eog ts  oim rr e rroe lfrl
# no
#  oid n  c,o t  iamsdrldr o fm owiu rtansrrrarrmeontt cras tsao t   nar,mw t o andervsde rronrssrsdovso dlr nuaresrsoaotasooe aot s ahoof lxrosn r
# rtrwo,lr o
# rtrodo  c s "itr   r  rdteotdrrroitl tc n n   o rr o-irrnosass er.foisrrr rrsrn odo a tro ieeooisaettnrdpeytrt  ro d drut tew laoetho ru aor crnl srrrettr oo, os ilp srswortrrtbeohgowif tptrs tod d,db oir t  msi
#
# --------- temperature: 1.2
# ttr oo, os ilp srswortrrtbeohgowif tptrs tod d,db oir t  msirrlrirtnefsdroaorou,dstr  ortsror s rsetds roidvssnrarouwsoet rdt dsrdclfmsvnurtn  adtorolt-d  t soeoa
# lobruadeiwscc
# ?ttrattedeeensooace rtedrot t oraed ta:tlcen :nowsptat adlas) s naudrocf,af w vdy m rfatr
# tsfeotghc nainmaeesstodtr-tc e 1o
# e rr
# o nreso od ortiseetnnwttror n gnan a wn s niotcnegno a k r,ssd  roourle rfr?aeotersre    ete ,ngrwot lflceahnenntattrwah  h forpootr-thsert tnwfr isdadvw
#
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 363s 2ms/step - loss: 3.2803
# --- Generating with seed: " in the north of germany it
# is stronger than in central germ"
# --------- temperature: 0.2
#  in the north of germany it
# is stronger than in central ...
#
# --------- temperature: 0.5
# ppporopppetreprtrrpeprttprrtptoptprtptttprppttrppepppppprtpptevetepoeeptrlotrttoprprtonsppttnrnrtptpporr eppprperpttrrop toeptsnprooppnoeret opproorpppprtrtrpprotrp rrpntoepropoooptotp pprrtotrilpolprlrprulroronlproprppopeoooeotrltrrpeolptpoelosetlp ppprreterrep ttpepetpepttttelprttptdtrtprprpgppprrdptrppinltrpooanetpurpppprspluorotreoproprsdrptpotprt npdppsnrtppp pareorepropprptueolnrdttpptprelorpi propterrptlseoro trrrtpppnerpelppeiarorttooptpdsnrptstppp
#
# --------- temperature: 1.0
# pi propterrptlseoro trrrtpppnerpelppeiarorttooptpdsnrptstpppntsrpesndttprtiprt etrfa
#  rrrrdnnetpp aetnorvrrsotretrnlvle uoctlnirltd pv  isnrpnvtlosape,otfo olnaiep p  ptropertief ouirrrroplitjolorrdtnerheretafapetrrsstepppk,opopopnfnpl,ohtphrpl
# oernvdsortpuropeoptootadeeoponnvepptopnbssgtpnyrsanptloprp owpsitpp yermcdgtirrotfvopiorpdsnentnoeppmolrtttnonpiepepneyrnppowopoeppdjtoemrpsvomottruev:tearprereancrmepsipptenrgydupt adapltfdcntdroynyrreutdivnit iop
#
# --------- temperature: 1.2
# rprereancrmepsipptenrgydupt adapltfdcntdroynyrreutdivnit iopklopt srpepbuol aiotn,pmp
#  atlteltptl
# dttu"ul,eatr
# rtolr
# o tosrs t nnjtnyppu.aj ppnrterelvltneplopjhwhc!ophbto  v
# eaomerdprd
# ntto
# le vobuiqnpoba.beforsest
# lbsr anplv a nritrvappopx egp tjneedtdprvtpartapdaraloorrernprlas npptawo rinsnlotaetltrtnss- a
# plgtrlogrornnptdtpegrvpypip
# fvrhnv,nbwntaptojpnetiupvrrpttstdrriioeet peivdt pttosptolsl ovontrrflvlv
# n,todslp
# sotppxs,aororaottoo
# proipei
# ltsprttr
#
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 367s 2ms/step - loss: 3.2775
# --- Generating with seed: "mited kind in comparison with the promises
# of religion.
#
#
# 12"
# --------- temperature: 0.2
# mited kind in comparison with the promises
# of religion.
#
#
# 12eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeoeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee eeeeeeeeee eeeeeeeeeeee
#
# --------- temperature: 0.5
# eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee eeeeeeeeee eeeeeeeeeeeeeeeeeeeeieaeeoeiiee eeeiieeeei sitoeie ee  eeepee peeeeee eeeeeeeeeeeeieee eeettsieeie eie peeeeeoeeeeespoeeoeeeeeeeeeeseeeeaseeieeeee eieeeeeeia aaeeieaeeeeeeea oeieeeieeei e seaeeeeeeeoeeeeeeeeeeeeeeaeeehe eeieeeeeeeee eeeeaeeeei eeeeeee eeeieeeeeeeeea eeeege eleaoeeeeeeeee ee
# eieeeeeeeeep eeeei eeeee peeeteeeeeeeeepeeeeeeeeee eipee eaeteieieteeeeeeeeeeeeeeaseeeeeieeeeeeeeeeietii eeofeeiieeeeeie
#
# --------- temperature: 1.0
# teieieteeeeeeeeeeeeeeaseeeeeieeeeeeeeeeietii eeofeeiieeeeeieeicptg
# mw evilsepeojeee r "usfteieegifheoieieieec eehi iaoeoteeek
# eae yihoprabeoeppooheoa ttmeat ga or hisittoee ttgoe eap  eeofse ihe igoyeerioyle uaipes
# e o
# p-io
# ddlbpetplies-p e  s eeeh
# eptodeie efua beepu
# reme ecpeutooi tei
# aat to pllotpoepem  ee
#
#  apuseeneniefe at
# upepiwi ne oblfxgoeis hbe etee eeeeh
#  aouptehipy heaioiee eeospieef afeepiueatipma oty p eetaaetteptasenatt
# eeib
# ee  et ea e ees
#
# --------- temperature: 1.2
# afeepiueatipma oty p eetaaetteptasenatt
# eeib
# ee  et ea e eess eegfhnetbe oegreieleg elayte.aepm
# t hgie r l oeie tteyoi aehoserooseeeobeeoithmioee
# oeera ei  fierppteteoorsi
# eeetil iieiti emutebt  yoepeoon-oeepyei
#  n
# aegeeeeehectleit;a igop-i i  eieeasi bheoois neela sgbiaeeu
# oueeeepceer oeesee
# beaeoayeue eeg -ieofeefeie
# tssbf oie aeroowc miioobyeoe  hnieecuea a-eefileipi seieo ueffprlppmeocgeio
# leieyghcvepmloo nps
# eeieteeefahlayig eeayo  ieo
# oeefshfr eepo
#
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 364s 2ms/step - loss: 3.2774
# --- Generating with seed: "s, the more searchingly do men look to the
# elimination of ev"
# --------- temperature: 0.2
# s, the more searchingly do men look to the
# elimination of evrrarrrarrrryrrrrarrrrarararrrarayrarararryraararrrrayrrrrryaraarrrrrrrrrarrrrraa,ararrrrrrraraarararrrarrarrrraararrrrrrrrrrraa,rraayrr,raarrrrraryyryrrrrarrrrrarrarrarrrrrrrrrrrrrarayarrrrarrrrrrraaryaraararrrrrrrarrrrrrarraararaarrrrrrrrarrrrarrarrrrrrrrrrrarrarrarrraarryrrarrarrarrrrrarararrrrrarrrarrarrrrrrarrrrrraarrnaaarrrarrrrraarrrrrrrr,rrarrrr,rrararrrrrarrrarrararrarrrarraarrararar,rrrrr
#
# --------- temperature: 0.5
# rrrrrr,rrarrrr,rrararrrrrarrrarrararrarrrarraarrararar,rrrrrrrrrasaarrrrn)c,,aayerrr,, yrarrnr,craayrrmryead,rracr,rrrrry,rrrycyryrrrraryar,r,rrr rhdra,ay,cnrf,rary rnyarnrraraarayrnanrrfrnncarratryfaaarraarhac arrnya rrrrraarc c rarrarra rnr yrfa,ar,yrnraaraor arc,rrnarorraryc y farraryaayfaarar roaaar,rnaraacnaarrarrayrrroyarracryrayarryadryayrarn-aoan ar rarnyara
# aaarc, rarraaaayararyrr,afar,r,,araarnnraasrrnr,rrcrrnarrr yyaarraarnyaaryararrrryya rym ar
#
# --------- temperature: 1.0
# ,araarnnraasrrnr,rrcrrnarrr yyaarraarnyaaryararrrryya rym arhmrfna nsamm,maccaurfayrryarayr,, ra,mmnaylnyhrcav,prt,nca),fe rmfyrratcqnao,,arg,rerfnfsn,,yonnpyat-a atr,syaemaaa adayaum rarurttya
# mfd)fyaaa)mc)ty ,rrhnasrfr,ymr h  twyhh rr!yrhyhahyrrsrbrprvtmarerm
#
# rr,aefyycnadt,fo cuwsu,,hy tras rieerycm o,m ,caleacana
# a,arl tr)r,rfs,rcoaasmmnc oyramu,rnac hninrcuynryayrasardagd,rt
# ,tmana tnyc,a,osrryyrarn,p,ydnnaifat,yyyetyhausfarsa)aey
# rturydrabcf,adan rr
#
# --------- temperature: 1.2
# rryyrarn,p,ydnnaifat,yyyetyhausfarsa)aey
# rturydrabcf,adan rrgb
# muyihrtic,efeahstucrrrcsrss aa)r
# sae
# ) yydshcsmf,,rduauomgnarcle,cyhrl
# yyrai rynreyoad-a brymiuy,eafrrrfdma,avr vnram- n flrrmarayhhmtmaca,cemss ycrarr-fyyahnsan
# hfarsy
# h r,rrhaur)asnaurmrtcymaaauib,cmdyysercnonrarf rmeacd,fcnr"
# nyr)r ,   wrx raa mvmh,rnu-nrnn:cyca)cora)
# crrie ytsuf,n
# a,a r)yf flcaryyrh,hiri,s sicrrnofaihy ,s
# yrryu,car-a)cas,midf!c
# y)a qrapdrrdgcsatpah,nrmcfdaray edl),rrr  ,na
#
# epoch 22
# Epoch 1/1
# 155136/200278 [======================>.......] - ETA: 1:25 - loss: 3.2749
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f5da77ac99b5> in <module>()
#      13
#      14     # fit the model for one iteration on the data
# ---> 15     model.fit (x, y, batch_size = 128, epochs = 1)
#      16     #model.save('nietzsche_generate.h5')
#      17
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1397           ret = tf_session.TF_SessionRunCallable(
#    1398               self._session._session, self._handle, args, status,
# -> 1399               run_metadata_ptr)
#    1400         if run_metadata:
#    1401           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
